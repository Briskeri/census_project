# %%
pip install sqlalchemy psycopg2 censusdata pandas

# %%
import pandas as pd
import censusdata
import psycopg2
from sqlalchemy import create_engine

engine = create_engine('postgresql://naya:urigoren@104.155.40.113:5432/nrich')

# %%
divorce= censusdata.download('acs5', 2015, censusdata.censusgeo([('state','*')]),
                    ['B12002_080E','B12002_081E','B12002_082E','B12002_083E','B12002_084E','B12002_085E','B12002_086E','B12002_087E','B12002_088E','B12002_089E','B12002_090E','B12002_091E','B12002_092E','B12002_093E','B12002_094E'])
divorce.columns=['Divorced', 'Divorced_15_to_17_years', 'Divorced_18_to_19_years', 'Divorced_20_to_24_years', 'Divorced_25_to_29_years', 'Divorced_30_to_34_years', 'Divorced_35_to_39_years', 'Divorced_40_to_44_years', 'Divorced_45_to_49_years','Divorced_50_to_54_years', 'Divorced_55_to_59_years', 'Divorced_60_to_64_years', 'Divorced_65_to_74_years', 'Divorced_75_to_84_years', 'Divorced_85_years_and_over']
divorce.describe()
# Out:
#            Divorced  Divorced_15_to_17_years  Divorced_18_to_19_years  \
# count  5.200000e+01                52.000000                52.000000
# mean   2.336540e+05                41.019231                55.596154
# std    2.403195e+05                53.983109                74.985818
# min    2.158500e+04                 0.000000                 0.000000
# 25%    6.948300e+04                 3.500000                 8.000000
# 50%    1.839695e+05                18.000000                35.500000
# 75%    2.863942e+05                65.000000                68.000000
# max    1.223367e+06               313.000000               449.000000
#
#        Divorced_20_to_24_years  Divorced_25_to_29_years  \
# count                52.000000                52.000000
# mean               1240.346154              6160.769231
# std                1316.612169              6461.415457
# min                  62.000000               410.000000
# ...

# %%
divorce
# Out:
#                                                     Divorced  \
# Alabama: Summary level: 040, state:01                 213443
# Alaska: Summary level: 040, state:02                   32365
# Arizona: Summary level: 040, state:04                 283950
# Arkansas: Summary level: 040, state:05                139710
# California: Summary level: 040, state:06             1223367
# Colorado: Summary level: 040, state:08                217735
# Connecticut: Summary level: 040, state:09             127191
# Delaware: Summary level: 040, state:10                 36455
# District of Columbia: Summary level: 040, state:11     21585
# Florida: Summary level: 040, state:12                 900277
# Georgia: Summary level: 040, state:13                 373114
# Hawaii: Summary level: 040, state:15                   48072
# Idaho: Summary level: 040, state:16                    69051
# Illinois: Summary level: 040, state:17                431683
# ...

# %%
#יצירת מילון
list_statecode = [str(k).split(',')[1][7:9] for k in divorce.index.values]
list_names = [str(k).split(',')[0].split(':')[0] for k in divorce.index.values]
milon=dict(zip(list_statecode,list_names))
milon
# Out:
# {'01': 'Alabama',
#  '02': 'Alaska',
#  '04': 'Arizona',
#  '05': 'Arkansas',
#  '06': 'California',
#  '08': 'Colorado',
#  '09': 'Connecticut',
#  '10': 'Delaware',
#  '11': 'District of Columbia',
#  '12': 'Florida',
#  '13': 'Georgia',
#  '15': 'Hawaii',
#  '16': 'Idaho',
#  '17': 'Illinois',
#  '18': 'Indiana',
#  '19': 'Iowa',
#  '20': 'Kansas',
#  '21': 'Kentucky',
#  '22': 'Louisiana',
#  '23': 'Maine',
#  '24': 'Maryland',
#  '25': 'Massachusetts',
#  '26': 'Michigan',
#  '27': 'Minnesota',
#  '28': 'Mississippi',
#  '29': 'Missouri',
#  '30': 'Montana',
#  '31': 'Nebraska',
#  '32': 'Nevada',
#  '33': 'New Hampshire',
#  '34': 'New Jersey',
#  '35': 'New Mexico',
#  '36': 'New York',
#  '37': 'North Carolina',
#  '38': 'North Dakota',
#  '39': 'Ohio',
#  '40': 'Oklahoma',
#  '41': 'Oregon',
#  '42': 'Pennsylvania',
#  '44': 'Rhode Island',
#  '45': 'South Carolina',
#  '46': 'South Dakota',
#  '47': 'Tennessee',
#  '48': 'Texas',
#  '49': 'Utah',
#  '50': 'Vermont',
# ...

# %%
#שליפה לפי הזנת קוד מדינה
num_state=input("please enter your number State ")
search=None



if num_state  not in milon:
    
    print('Sorry, you need select number State from the list')

else:
    search= censusdata.download('acs5', 2015, censusdata.censusgeo([('state',num_state)]),
                                ['B12002_080E','B12002_081E','B12002_082E','B12002_083E','B12002_084E','B12002_085E','B12002_086E','B12002_087E','B12002_088E','B12002_089E','B12002_090E','B12002_091E','B12002_092E','B12002_093E','B12002_094E'])

    search.columns=['Divorced', 'Divorced_15_to_17_years', 'Divorced_18_to_19_years', 'Divorced_20_to_24_years', 'Divorced_25_to_29_years', 'Divorced_30_to_34_years', 'Divorced_35_to_39_years', 'Divorced_40_to_44_years', 'Divorced_45_to_49_years','Divorced_50_to_54_years', 'Divorced_55_to_59_years', 'Divorced_60_to_64_years', 'Divorced_65_to_74_years', 'Divorced_75_to_84_years', 'Divorced_85_years_and_over']
search
# Out:
# please enter your number State 06
#                                           Divorced  Divorced_15_to_17_years  \
# California: Summary level: 040, state:06   1223367                      313
#
#                                           Divorced_18_to_19_years  \
# California: Summary level: 040, state:06                      449
#
#                                           Divorced_20_to_24_years  \
# California: Summary level: 040, state:06                     5520
#
#                                           Divorced_25_to_29_years  \
# California: Summary level: 040, state:06                    30513
#
#                                           Divorced_30_to_34_years  \
# California: Summary level: 040, state:06                    63683
#
#                                           Divorced_35_to_39_years  \
# California: Summary level: 040, state:06                    92264
#
#                                           Divorced_40_to_44_years  \
# ...

# %%
#הצגה של שיעורי הגירושים באחוזים


search['Divorced_15_to_17_years'] = (round((search['Divorced_15_to_17_years']/search['Divorced'])*100,2))
search['Divorced_18_to_19_years'] = round((search['Divorced_18_to_19_years']/search['Divorced'])*100,2)
search['Divorced_20_to_24_years'] = round((search['Divorced_20_to_24_years']/search['Divorced'])*100,2)
search['Divorced_25_to_29_years'] = round((search['Divorced_25_to_29_years']/search['Divorced'])*100,2)
search['Divorced_30_to_34_years'] = round((search['Divorced_30_to_34_years']/search['Divorced'])*100,2)
search['Divorced_35_to_39_years'] = round((search['Divorced_35_to_39_years']/search['Divorced'])*100,2)
search['Divorced_40_to_44_years'] = round((search['Divorced_40_to_44_years']/search['Divorced'])*100,2)
search['Divorced_45_to_49_years'] = round((search['Divorced_45_to_49_years']/search['Divorced'])*100,2)
search['Divorced_50_to_54_years'] = round((search['Divorced_50_to_54_years']/search['Divorced'])*100,2)
search['Divorced_55_to_59_years'] = round((search['Divorced_55_to_59_years']/search['Divorced'])*100,2)
search['Divorced_60_to_64_years'] = round((search['Divorced_60_to_64_years']/search['Divorced'])*100,2)
search['Divorced_65_to_74_years'] = round((search['Divorced_65_to_74_years']/search['Divorced'])*100,2)
search['Divorced_75_to_84_years'] = round((search['Divorced_75_to_84_years']/search['Divorced'])*100,2)
search['Divorced_85_years_and_over'] = round((search['Divorced_85_years_and_over']/search['Divorced'])*100,2)

search['Divorced'] =100.00



search
# Out:
#                                           Divorced  Divorced_15_to_17_years  \
# California: Summary level: 040, state:06     100.0                     0.03
#
#                                           Divorced_18_to_19_years  \
# California: Summary level: 040, state:06                     0.04
#
#                                           Divorced_20_to_24_years  \
# California: Summary level: 040, state:06                     0.45
#
#                                           Divorced_25_to_29_years  \
# California: Summary level: 040, state:06                     2.49
#
#                                           Divorced_30_to_34_years  \
# California: Summary level: 040, state:06                     5.21
#
#                                           Divorced_35_to_39_years  \
# California: Summary level: 040, state:06                     7.54
#
#                                           Divorced_40_to_44_years  \
# ...

# %%
pd.DataFrame(divorce[divorce.Divorced_15_to_17_years == divorce.Divorced_15_to_17_years.max()])
# Out:
#                                           Divorced  Divorced_15_to_17_years  \
# California: Summary level: 040, state:06   1223367                      313
#
#                                           Divorced_18_to_19_years  \
# California: Summary level: 040, state:06                      449
#
#                                           Divorced_20_to_24_years  \
# California: Summary level: 040, state:06                     5520
#
#                                           Divorced_25_to_29_years  \
# California: Summary level: 040, state:06                    30513
#
#                                           Divorced_30_to_34_years  \
# California: Summary level: 040, state:06                    63683
#
#                                           Divorced_35_to_39_years  \
# California: Summary level: 040, state:06                    92264
#
#                                           Divorced_40_to_44_years  \
# ...

# %%
divorce.to_sql("im_divorce_rate_by_state", engine ,if_exists='replace',index=False)
