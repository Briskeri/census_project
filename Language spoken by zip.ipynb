# %%
pip install sqlalchemy psycopg2 censusdata pandas

# %%
import pandas as pd
import censusdata
import psycopg2
from sqlalchemy import create_engine

engine = create_engine('postgresql://naya:urigoren@104.155.40.113:5432/nrich')

# %%
spokenlang = censusdata.download('acs5', 2015, censusdata.censusgeo([('place','*')]),
                    ['B06007_002E','B06007_003E','B06007_006E','B06007_001E'])

spokenlang.columns=['Only_English', 'Spanish','Other_languages','Total']
spokenlang.describe()
# Out:
#        Only_English       Spanish  Other_languages         Total
# count  2.932100e+04  2.932100e+04     2.932100e+04  2.932100e+04
# mean   5.663736e+03  1.161518e+03     6.890928e+02  7.514346e+03
# std    3.610872e+04  1.770682e+04     1.277667e+04  6.320998e+04
# min    0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 25%    2.760000e+02  0.000000e+00     0.000000e+00  3.110000e+02
# 50%    9.120000e+02  1.800000e+01     1.200000e+01  1.021000e+03
# 75%    3.293000e+03  1.740000e+02     1.060000e+02  3.837000e+03
# max    4.009822e+06  1.932321e+06     1.928789e+06  7.870932e+06

# %%
spokenlang = censusdata.download('acs5', 2015, censusdata.censusgeo([('state', '*'),('place','*')]),
                                     ['B06007_002E','B06007_003E','B06007_006E','B06007_001E'])
                   
spokenlang.columns=['Only_English', 'Spanish','Other_languages','Total']
spokenlang
# Out:
#                                                     Only_English  Spanish  \
# Berwind CDP, West Virginia: Summary level: 160,...         431.0      0.0
# Bethany town, West Virginia: Summary level: 160...        1093.0      2.0
# Bethlehem village, West Virginia: Summary level...        2369.0     13.0
# Beverly town, West Virginia: Summary level: 160...         565.0      0.0
# Big Chimney CDP, West Virginia: Summary level: ...         301.0      0.0
# Big Creek CDP, West Virginia: Summary level: 16...         331.0      0.0
# Big Sandy CDP, West Virginia: Summary level: 16...         185.0      0.0
# Birch River CDP, West Virginia: Summary level: ...          35.0      0.0
# Blacksville town, West Virginia: Summary level:...         145.0      0.0
# Blennerhassett CDP, West Virginia: Summary leve...        2621.0     34.0
# Bluefield city, West Virginia: Summary level: 1...        9621.0    129.0
# Bluewell CDP, West Virginia: Summary level: 160...        2370.0      0.0
# ...

# %%
spokenlang.index.values
# Out:
# array([censusgeo((('state', '54'), ('place', '06748')), 'Berwind CDP, West Virginia'),
#        censusgeo((('state', '54'), ('place', '06844')), 'Bethany town, West Virginia'),
#        censusgeo((('state', '54'), ('place', '06940')), 'Bethlehem village, West Virginia'),
#        ...,
#        censusgeo((('state', '36'), ('place', '58486')), 'Plandome Heights village, New York'),
#        censusgeo((('state', '36'), ('place', '58497')), 'Plandome Manor village, New York'),
#        censusgeo((('state', '36'), ('place', '58541')), 'Plattekill CDP, New York')],
#       dtype=object)

# %%
test = [str(k).split(',')[2] for k in spokenlang.index.values]
test
# Out:
# [' state:54> place:06748',
#  ' state:54> place:06844',
#  ' state:54> place:06940',
#  ' state:54> place:06988',
#  ' state:54> place:07204',
#  ' state:54> place:07228',
#  ' state:54> place:07516',
#  ' state:54> place:07756',
#  ' state:54> place:08092',
#  ' state:54> place:08308',
#  ' state:54> place:08524',
#  ' state:54> place:08764',
#  ' state:54> place:08836',
#  ' state:54> place:08932',
#  ' state:54> place:08956',
#  ' state:54> place:09100',
#  ' state:54> place:09364',
#  ' state:54> place:09676',
#  ' state:54> place:09700',
#  ' state:54> place:09796',
#  ' state:54> place:09844',
#  ' state:54> place:09868',
#  ' state:54> place:09964',
#  ' state:54> place:10180',
#  ' state:54> place:10420',
#  ' state:54> place:10852',
#  ' state:54> place:10876',
#  ' state:54> place:10948',
#  ' state:54> place:11188',
#  ' state:54> place:11212',
#  ' state:54> place:11284',
#  ' state:54> place:11620',
#  ' state:54> place:11716',
#  ' state:54> place:12124',
# ...

# %%
spokenlang.index.values
list_statecode = [str(k).split(',')[2].split(':')[1].split('>')[0] for k in spokenlang.index.values]
list_zipcode = [str(v).split(',')[2][17:22] for v in spokenlang.index.values]
milon=dict(zip(list_zipcode,list_statecode))
milon
# Out:
# {'06748': '54',
#  '06844': '54',
#  '06940': '46',
#  '06988': '54',
#  '07204': '54',
#  '07228': '54',
#  '07516': '27',
#  '07756': '54',
#  '08092': '36',
#  '08308': '54',
#  '08524': '27',
#  '08764': '54',
#  '08836': '54',
#  '08932': '54',
#  '08956': '13',
#  '09100': '40',
#  '09364': '54',
#  '09676': '54',
#  '09700': '30',
#  '09796': '48',
#  '09844': '54',
#  '09868': '48',
#  '09964': '27',
#  '10180': '31',
#  '10420': '38',
#  '10852': '48',
#  '10876': '48',
#  '10948': '54',
#  '11188': '21',
#  '11212': '48',
#  '11284': '54',
#  '11620': '37',
#  '11716': '48',
#  '12124': '27',
#  '12436': '54',
#  '12484': '27',
#  '13108': '48',
#  '13468': '54',
#  '13525': '54',
#  '13684': '48',
#  '13756': '06',
#  '13924': '27',
#  '14212': '29',
#  '14308': '54',
#  '14524': '54',
#  '14600': '42',
#  '14610': '54',
#  '14630': '54',
#  '14692': '48',
#  '14716': '48',
#  '14775': '54',
#  '14812': '54',
#  '15028': '48',
#  '15076': '54',
#  '15628': '48',
# ...

# %%
#select zip_code
serchzipcode=None
zip_code=input("please enter your zip code ")

if zip_code  not in milon:
    
    print('Sorry, you need select Zip code with 5 digits from the milon')
else: 
    serchzipcode = censusdata.download('acs5', 2015, censusdata.censusgeo([('state', milon[zip_code]),('place', zip_code)]),
                                     ['B06007_002E','B06007_003E','B06007_006E','B06007_001E'])
                   
    serchzipcode.columns=['Only_English', 'Spanish','Other_languages','Total']

serchzipcode

# %%
spokenlang.to_sql("im_language_spoken_by_zip", engine ,if_exists='replace',index=False)

# %%
# Get all values of a specific table
sql = """
select * from information_schema.columns where table_name = 'im_language_spoken_by_zip'
"""
df = pd.read_sql(sql, con=engine)
df
# Out:
#   table_catalog table_schema                 table_name      column_name  \
# 0         nrich       public  im_language_spoken_by_zip     Only_English
# 1         nrich       public  im_language_spoken_by_zip          Spanish
# 2         nrich       public  im_language_spoken_by_zip  Other_languages
# 3         nrich       public  im_language_spoken_by_zip            Total
#
#    ordinal_position column_default is_nullable         data_type  \
# 0                 1           None         YES  double precision
# 1                 2           None         YES  double precision
# 2                 3           None         YES  double precision
# 3                 4           None         YES  double precision
#
#   character_maximum_length character_octet_length  ...  is_identity  \
# 0                     None                   None  ...           NO
# 1                     None                   None  ...           NO
# ...

# %%
# Get all values of a specific table
sql = """
select * from im_language_spoken_by_zip

"""
df = pd.read_sql(sql, con=engine)
df
# Out:
#        Only_English  Spanish  Other_languages    Total
# 0             431.0      0.0              0.0    431.0
# 1            1093.0      2.0             31.0   1126.0
# 2            2369.0     13.0             40.0   2422.0
# 3             565.0      0.0              4.0    569.0
# 4             301.0      0.0              0.0    301.0
# 5             331.0      0.0              0.0    331.0
# 6             185.0      0.0              0.0    185.0
# 7              35.0      0.0              0.0     35.0
# 8             145.0      0.0              0.0    145.0
# 9            2621.0     34.0              0.0   2655.0
# 10           9621.0    129.0             93.0   9843.0
# 11           2370.0      0.0             22.0   2392.0
# 12           1266.0      0.0             14.0   1280.0
# 13           1124.0      0.0             14.0   1138.0
# 14            494.0     16.0              0.0    510.0
# 15            703.0     24.0             29.0    756.0
# ...
