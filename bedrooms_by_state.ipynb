# %%
pip install sqlalchemy psycopg2 censusdata pandas

# %%
import pandas as pd
import censusdata
import psycopg2
from sqlalchemy import create_engine

engine = create_engine('postgresql://naya:urigoren@104.155.40.113:5432/nrich')

# %%
bedrooms= censusdata.download('acs5', 2015, censusdata.censusgeo([('state','*')]),
                    ['B25041_002E','B25041_003E','B25041_004E','B25041_005E','B25041_006E','B25041_007E','B25041_001E'])

bedrooms.columns=['No_bedroom', '1_bedroom','2_bedrooms','3_bedrooms','4_bedrooms','5_or_more_bedrooms','Total']
bedrooms.describe()
# Out:
#           No_bedroom     1_bedroom    2_bedrooms    3_bedrooms    4_bedrooms  \
# count      52.000000  5.200000e+01  5.200000e+01  5.200000e+01  5.200000e+01
# mean    58378.423077  2.861664e+05  6.880085e+05  1.033636e+06  4.188692e+05
# std     87688.726213  3.825052e+05  7.571617e+05  1.012265e+06  4.407307e+05
# min      4288.000000  2.412900e+04  6.770100e+04  6.323000e+04  2.506800e+04
# 25%     18794.000000  7.528325e+04  2.112130e+05  2.955282e+05  1.216245e+05
# 50%     30824.000000  1.567195e+05  4.871685e+05  8.170800e+05  2.679265e+05
# 75%     56891.250000  2.946988e+05  7.910745e+05  1.183800e+06  5.029700e+05
# max    508802.000000  1.938660e+06  3.870870e+06  4.626151e+06  2.307505e+06
#
#        5_or_more_bedrooms         Total
# count           52.000000  5.200000e+01
# mean        109604.980769  2.594663e+06
# std         110285.851133  2.726434e+06
# min          11029.000000  2.666300e+05
# 25%          30039.500000  7.889150e+05
# ...

# %%
bedrooms= censusdata.download('acs5', 2015, censusdata.censusgeo([('state','*')]),
                    ['B25041_002E','B25041_003E','B25041_004E','B25041_005E','B25041_006E','B25041_007E','B25041_001E'])

bedrooms.columns=['No_bedroom', '1_bedroom','2_bedrooms','3_bedrooms','4_bedrooms','5_or_more_bedrooms','Total']
bedrooms
# Out:
#                                                     No_bedroom  1_bedroom  \
# Alabama: Summary level: 040, state:01                    26431     134181
# Alaska: Summary level: 040, state:02                     19164      43742
# Arizona: Summary level: 040, state:04                    72487     331246
# Arkansas: Summary level: 040, state:05                   23141      96586
# California: Summary level: 040, state:06                508802    1938660
# Colorado: Summary level: 040, state:08                   47608     260038
# Connecticut: Summary level: 040, state:09                31732     183370
# Delaware: Summary level: 040, state:10                    4288      29920
# District of Columbia: Summary level: 040, state:11       25310      94598
# Florida: Summary level: 040, state:12                   171515     954017
# Georgia: Summary level: 040, state:13                    55172     301838
# Hawaii: Summary level: 040, state:15                     26408      72307
# ...

# %%
print(bedrooms.index.values)
print(type(bedrooms.index.values))
# Out:
# [censusgeo((('state', '01'),), 'Alabama')
#  censusgeo((('state', '02'),), 'Alaska')
#  censusgeo((('state', '04'),), 'Arizona')
#  censusgeo((('state', '05'),), 'Arkansas')
#  censusgeo((('state', '06'),), 'California')
#  censusgeo((('state', '08'),), 'Colorado')
#  censusgeo((('state', '09'),), 'Connecticut')
#  censusgeo((('state', '10'),), 'Delaware')
#  censusgeo((('state', '11'),), 'District of Columbia')
#  censusgeo((('state', '12'),), 'Florida')
#  censusgeo((('state', '13'),), 'Georgia')
#  censusgeo((('state', '15'),), 'Hawaii')
#  censusgeo((('state', '16'),), 'Idaho')
#  censusgeo((('state', '17'),), 'Illinois')
#  censusgeo((('state', '18'),), 'Indiana')
#  censusgeo((('state', '19'),), 'Iowa')
#  censusgeo((('state', '20'),), 'Kansas')
#  censusgeo((('state', '21'),), 'Kentucky')
#  censusgeo((('state', '22'),), 'Louisiana')
#  censusgeo((('state', '23'),), 'Maine')
#  censusgeo((('state', '24'),), 'Maryland')
#  censusgeo((('state', '25'),), 'Massachusetts')
# ...

# %%
list_statecode = [str(k).split(',')[1][7:9] for k in bedrooms.index.values]
list_names = [str(k).split(',')[0].split(':')[0] for k in bedrooms.index.values]
milon=dict(zip(list_statecode,list_names))
milon
# Out:
# {'01': 'Alabama',
#  '02': 'Alaska',
#  '04': 'Arizona',
#  '05': 'Arkansas',
#  '06': 'California',
#  '08': 'Colorado',
#  '09': 'Connecticut',
#  '10': 'Delaware',
#  '11': 'District of Columbia',
#  '12': 'Florida',
#  '13': 'Georgia',
#  '15': 'Hawaii',
#  '16': 'Idaho',
#  '17': 'Illinois',
#  '18': 'Indiana',
#  '19': 'Iowa',
#  '20': 'Kansas',
#  '21': 'Kentucky',
#  '22': 'Louisiana',
#  '23': 'Maine',
#  '24': 'Maryland',
#  '25': 'Massachusetts',
#  '26': 'Michigan',
#  '27': 'Minnesota',
#  '28': 'Mississippi',
#  '29': 'Missouri',
#  '30': 'Montana',
#  '31': 'Nebraska',
#  '32': 'Nevada',
#  '33': 'New Hampshire',
#  '34': 'New Jersey',
#  '35': 'New Mexico',
#  '36': 'New York',
#  '37': 'North Carolina',
#  '38': 'North Dakota',
#  '39': 'Ohio',
#  '40': 'Oklahoma',
#  '41': 'Oregon',
#  '42': 'Pennsylvania',
#  '44': 'Rhode Island',
#  '45': 'South Carolina',
#  '46': 'South Dakota',
#  '47': 'Tennessee',
#  '48': 'Texas',
#  '49': 'Utah',
#  '50': 'Vermont',
# ...

# %%
#שליפה לפי הזנת קוד מדינה


num_state=input("please enter your number State ")
search=None
if num_state  not in milon:
    
    print('Sorry, you need select number State from the list')

else:
    search= censusdata.download('acs5', 2015, censusdata.censusgeo([('state',num_state)]),
                    ['B25041_002E','B25041_003E','B25041_004E','B25041_005E','B25041_006E','B25041_007E','B25041_001E'])

    search.columns=['No_bedroom', '1_bedroom','2_bedrooms','3_bedrooms','4_bedrooms','5_or_more_bedrooms','Total']
search
# Out:
# please enter your number State 11
#                                                     No_bedroom  1_bedroom  \
# District of Columbia: Summary level: 040, state:11       25310      94598
#
#                                                     2_bedrooms  3_bedrooms  \
# District of Columbia: Summary level: 040, state:11       83458       63230
#
#                                                     4_bedrooms  \
# District of Columbia: Summary level: 040, state:11       25068
#
#                                                     5_or_more_bedrooms   Total
# District of Columbia: Summary level: 040, state:11               11648  303312

# %%
#מציאת הקטגוריה המקסימלית לפי מדינה

search.values
a=search.values[0][0:5].argmax()
b=search.columns[a]

print (f'The maximum category is {b} with value of {milon[num_state]}')
# Out:
# The maximum category is 1_bedroom with value of District of Columbia

# %%
search.values[0][0:5].argmax()
# Out:
# 1

# %%
bedrooms.to_sql("im_bedrooms_by_state", engine ,if_exists='replace',index=False)

# %%
# Get all values of a specific table
sql = """
select * from information_schema.columns where table_name = 'im_bedrooms_by_state'
"""
df = pd.read_sql(sql, con=engine)
df
# Out:
#   table_catalog table_schema            table_name         column_name  \
# 0         nrich       public  im_bedrooms_by_state          No_bedroom
# 1         nrich       public  im_bedrooms_by_state           1_bedroom
# 2         nrich       public  im_bedrooms_by_state          2_bedrooms
# 3         nrich       public  im_bedrooms_by_state          3_bedrooms
# 4         nrich       public  im_bedrooms_by_state          4_bedrooms
# 5         nrich       public  im_bedrooms_by_state  5_or_more_bedrooms
# 6         nrich       public  im_bedrooms_by_state               Total
#
#    ordinal_position column_default is_nullable data_type  \
# 0                 1           None         YES    bigint
# 1                 2           None         YES    bigint
# 2                 3           None         YES    bigint
# 3                 4           None         YES    bigint
# 4                 5           None         YES    bigint
# ...

# %%
# Get all values of a specific table
sql = """
select * from im_bedrooms_by_state 

"""
df = pd.read_sql(sql, con=engine)
df
# Out:
#     No_bedroom  1_bedroom  2_bedrooms  3_bedrooms  4_bedrooms  \
# 0        26431     134181      525987     1098387      340998
# 1        19164      43742       82282      106743       45301
# 2        72487     331246      789109     1078244      499591
# 3        23141      96586      364170      666180      158484
# 4       508802    1938660     3870870     4626151     2307505
# 5        47608     260038      580462      764503      436333
# 6        31732     183370      405883      547408      255820
# 7         4288      29920       86241      185391       91155
# 8        25310      94598       83458       63230       25068
# 9       171515     954017     3067962     3494184     1182814
# 10       55172     301838      954114     1809184      750983
# 11       26408      72307      138975      186213       72536
# 12       11903      48972      163177      277790      123724
# 13      139397     614135     1532081     1946263      853239
# ...
